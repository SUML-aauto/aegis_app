# %%
# %pip install scikit-learn
# %pip install pandas

# %%
import sklearn
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
raw_dataset = pd.read_csv("insurance_update.csv", sep=";")

# %%
raw_dataset
# Out:
#              Make    Model  Manufacturing Year Fuel Type  Engine Power (HP)  \
# 0           Honda    Civic              2020.0    Hybrid              202.0
# 1             BMW       X3              2023.0    Diesel              431.0
# 2      Volkswagen     Golf              2019.0  Electric              144.0
# 3       Chevrolet   Malibu              2022.0    Hybrid              314.0
# 4           Tesla  Model 3              2018.0  Electric              395.0
# ...           ...      ...                 ...       ...                ...
# 10269         NaN      NaN                 NaN       NaN                NaN
# 10270         NaN      NaN                 NaN       NaN                NaN
# 10271         NaN      NaN                 NaN       NaN                NaN
# 10272         NaN      NaN                 NaN       NaN                NaN
# 10273         NaN      NaN                 NaN       NaN                NaN
#
# ...
